# %%
from google.colab import drive
import os

print("🔌 Conectando a Google Drive...")
# force_remount=True ayuda a refrescar si cambiaste archivos recientemente
drive.mount('/content/drive', force_remount=True)
# Out:
# 🔌 Conectando a Google Drive...
# Mounted at /content/drive

# %%
# Ajusta la ruta si tu carpeta se llama diferente
project_path = "/content/drive/MyDrive/Data_Extraction_Pipeline_with_Marker"

# %cd {project_path}

print(f"📂 Directorio actual: {os.getcwd()}")
print("Archivos detectados:")
# !ls -la
# Out:
# /content/drive/MyDrive/Data_Extraction_Pipeline_with_Marker
# 📂 Directorio actual: /content/drive/MyDrive/Data_Extraction_Pipeline_with_Marker
# Archivos detectados:
# total 494
# -rw------- 1 root root 202096 Dec 14 18:39 ASCO-Guidelines-data-extraction-run.ipynb
# drwx------ 2 root root   4096 Dec 14 18:36 data
# -rw------- 1 root root   1083 Dec 14 18:16 LICENSE.txt
# -rw------- 1 root root 289138 Dec 14 18:16 poetry.lock
# -rw------- 1 root root    435 Dec 14 18:16 pyproject.toml
# -rw------- 1 root root   2689 Dec 14 18:16 README.md
# -rw------- 1 root root     70 Dec 14 18:16 requirements.txt
# drwx------ 2 root root   4096 Dec 14 18:36 scripts

# %%
print("📦 Instalando Marker (Última Versión) y dependencias...")

# Instalamos marker-pdf y las utilidades necesarias
# El -q hace la instalación más silenciosa (menos ruido en pantalla)
# !pip install -q marker-pdf pymupdf pypdfium2 pydantic

print("✅ Instalación completada.")
# Out:
# 📦 Instalando Marker (Última Versión) y dependencias...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 5.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 3.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.9/188.9 kB 12.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.1/24.1 MB 112.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 223.2/223.2 kB 21.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.0/50.0 kB 4.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 948.6/948.6 kB 68.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 104.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 137.3 MB/s eta 0:00:00
# ...

# %%
print("🚀 Iniciando PHASE 1: Extracción con GPU...")
print("Esto puede tomar unos minutos dependiendo de la cantidad de PDFs.")
print("-" * 50)

# Ejecutamos el script como si estuviéramos en la terminal
# !python scripts/asco_marker_extraction.py

print("-" * 50)
print("✅ Fase 1 terminada. Revisa la carpeta 'data/marker_outputs' en tu Drive.")
# Out:
# 🚀 Iniciando PHASE 1: Extracción con GPU...
# Esto puede tomar unos minutos dependiendo de la cantidad de PDFs.
# --------------------------------------------------
# 2025-12-14 18:40:17.641518: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765737617.662354     889 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765737617.668394     889 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
print("✨ Iniciando PHASE 2 y 3: Verificación  y Validación...")
print("-" * 50)

# Ejecutamos el segundo script
# !python scripts/asco_pubmed_enrichment.py

print("-" * 50)
print("✅ Pipeline completo. Los archivos finales están en 'data/processed'.")
# Out:
# ✨ Iniciando PHASE 2 y 3: Verificación  y Validación...
# --------------------------------------------------
# Found 2 intermediate file(s). Starting enrichment...
#
# → Processing: jimenez-et-al-2025-postmastectomy-radiation-therapy-an-astro-asco-sso-clinical-practice-guideline.json
#   Searching by DOI: 10.1200/JCO-25-01747
#   Found PMID: 40955654
#   ✓ Success: Postmastectomy Radiation Therapy: An ASTRO-ASCO-SS...
#   ✓ Saved: jimenez-et-al-2025-postmastectomy-radiation-therapy-an-astro-asco-sso-clinical-practice-guideline_final.json
#
# → Processing: park-et-al-2025-sentinel-lymph-node-biopsy-in-early-stage-breast-cancer-asco-guideline-update.json
#   Searching by DOI: 10.1200/JCO-25-00099
#   Found PMID: 40209128
#   ✓ Success: Sentinel Lymph Node Biopsy in Early-Stage Breast C...
#   ✓ Saved: park-et-al-2025-sentinel-lymph-node-biopsy-in-early-stage-breast-cancer-asco-guideline-update_final.json
#
# ✓ Phase 2 & 3 complete!
#   - Validated documents: 2
#   - Failed documents: 0
# ...
